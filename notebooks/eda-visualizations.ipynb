# %% [markdown]
# # Introduction
# Here is an Exlporatory Data Analysis for Avito Demand Prediction Challenge where we're tasked estimating the sucess of online ads. We are provided dataset with tabular, text and image data.
# Our task is to predict an algorithm that predict demand for an online advertisement based on its full description (title, description, images, etc.), its context (geographically where it was posted, similar ads already posted) and historical demand for similar ads in similar contexts.
#
# Let's prepare and have a look at the dataset.

# %% [markdown]
# # Preparations
# Here we load required libraries for data wrangling and visualization

# %%
import pandas as pd
from category_encoders.hashing import HashingEncoder
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
import gc
from scipy.sparse import csr_matrix, hstack
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import zipfile
import matplotlib.pyplot as plt

nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('russian'))

pd.set_option('precision', 5)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

MAX_FEATURES = 2000
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/vravuri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
train = pd.read_csv('../data/raw/train.csv', parse_dates=['activation_date'])
test = pd.read_csv('../data/raw/test.csv', parse_dates=['activation_date'])

# %% [markdown]
# ## Glimpse of dataset

# %%
train.head(5)
# Out:
#         item_id       user_id                 region              city  \
# 0  b912c3c6a6ad  e00f8ff2eaf9   Свердловская область      Екатеринбург
# 1  2dac0150717d  39aeb48f0017      Самарская область            Самара
# 2  ba83aefab5dc  91e2f88dd6e3     Ростовская область    Ростов-на-Дону
# 3  02996f1dd2ea  bf5cccea572d              Татарстан  Набережные Челны
# 4  7c90be56d2ab  ef50846afc0b  Волгоградская область         Волгоград
#
#   parent_category_name               category_name  \
# 0          Личные вещи  Товары для детей и игрушки
# 1      Для дома и дачи           Мебель и интерьер
# 2  Бытовая электроника               Аудио и видео
# 3          Личные вещи  Товары для детей и игрушки
# 4            Транспорт                  Автомобили
#
#                        param_1     param_2 param_3                  title  \
# 0    Постельные принадлежности         NaN     NaN  Кокоби(кокон для сна)
# 1                       Другое         NaN     NaN      Стойка для Одежды
# 2  Видео, DVD и Blu-ray плееры         NaN     NaN         Philips bluray
# 3         Автомобильные кресла         NaN     NaN             Автокресло
# 4                   С пробегом  ВАЗ (LADA)    2110         ВАЗ 2110, 2003
#
#                                          description       price  \
# 0  Кокон для сна малыша,пользовались меньше месяц...   400.00000
# 1          Стойка для одежды, под вешалки. С бутика.  3000.00000
# 2  В хорошем состоянии, домашний кинотеатр с blu ...  4000.00000
# 3                             Продам кресло от0-25кг  2200.00000
# 4                           Все вопросы по телефону. 40000.00000
#
#    item_seq_number activation_date user_type  \
# 0                2      2017-03-28   Private
# 1               19      2017-03-26   Private
# 2                9      2017-03-20   Private
# 3              286      2017-03-25   Company
# 4                3      2017-03-16   Private
#
#                                                image  image_top_1  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...   1008.00000
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...    692.00000
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...   3032.00000
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...    796.00000
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...   2264.00000
#
#    deal_probability
# 0           0.12789
# 1           0.00000
# 2           0.43177
# 3           0.80323
# 4           0.20797

# %%
train.isna().any()
# Out:
# item_id                 False
# user_id                 False
# region                  False
# city                    False
# parent_category_name    False
# category_name           False
# param_1                  True
# param_2                  True
# param_3                  True
# title                   False
# description              True
# price                    True
# item_seq_number         False
# activation_date         False
# user_type               False
# image                    True
# image_top_1              True
# deal_probability        False
# dtype: bool

# %% [markdown]
# ## Dataset Columns

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503424 entries, 0 to 1503423
# Data columns (total 18 columns):
# item_id                 1503424 non-null object
# user_id                 1503424 non-null object
# region                  1503424 non-null object
# city                    1503424 non-null object
# parent_category_name    1503424 non-null object
# category_name           1503424 non-null object
# param_1                 1441848 non-null object
# param_2                 848882 non-null object
# param_3                 640859 non-null object
# title                   1503424 non-null object
# description             1387148 non-null object
# price                   1418062 non-null float64
# item_seq_number         1503424 non-null int64
# activation_date         1503424 non-null datetime64[ns]
# user_type               1503424 non-null object
# image                   1390836 non-null object
# image_top_1             1390836 non-null float64
# deal_probability        1503424 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(13)
# memory usage: 206.5+ MB

# %% [markdown]
# There are total 18 features,
# 1. **item_id** - Ad id.
# 2. **user_id** - User id.
# 3. **region** - Ad region.
# 4. **city** - Ad city.
# 5. **parent_category_name** - Top level ad category as classified by Avito's ad model.
# 6. **category_name** - Fine grain ad category as classified by Avito's ad model.
# 7. **param_1** - Optional parameter from Avito's ad model.
# 8. **param_2** - Optional parameter from Avito's ad model.
# 9. **param_3** - Optional parameter from Avito's ad model.
# 10. **title** - Ad title.
# 11. **description** - Ad description.
# 12. **price** - Ad price.
# 13. **item_seq_number** - Ad sequential number for user.
# 14. **activation_date** - Date ad was placed.
# 15. **user_type** - User type.
# 16. **image** - Id code of image. Ties to a jpg file in train_jpg. Not every ad has an image.
# 17. **image_top_1** - Avito's classification code for the image.
#
# 18. **deal_probability** - The target variable. This is the likelihood that an ad actually sold something. It's not possible to verify every transaction with certainty, so this column's value can be any float from zero to one.

# %%
CATEGORY_FEATURES = ['region', 'city', 'parent_category_name', 'category_name', 'param_1', 'param_2', 
                     'param_3', 'user_type',  'image_top_1']
TEXT_FEATURES = ['title', 'description']
NUMBER_FEATURES = ['price', 'item_seq_number']
ID_FEATURES = ['item_id', 'user_id', 'image']
DATE_FEATURES = ['activation_date']
GENERATED_DATE_FEATURES = ['month', 'weekday', 'month_day', 'year_day']
TARGET_FEATURE = 'deal_probability'

ENCODED_CATEGORY_FEATURES = ['enc_region', 'enc_city', 'enc_parent_category_name', 'enc_category_name', 'enc_param_1', 'enc_param_2', 
                     'enc_param_3', 'enc_user_type',  'enc_image_top_1']

ALL_FEATURES = CATEGORY_FEATURES + TEXT_FEATURES + NUMBER_FEATURES + ID_FEATURES + DATE_FEATURES

# %%
# Encode category features using Hashing Encoder
he = HashingEncoder()
he.fit(train[CATEGORY_FEATURES].values)
train[ENCODED_CATEGORY_FEATURES] = he.transform(train[CATEGORY_FEATURES].values)
test[ENCODED_CATEGORY_FEATURES] = he.transform(test[CATEGORY_FEATURES].values)
# Dropping cateogory features.
train.drop(CATEGORY_FEATURES, axis=1, inplace=True)
test.drop(CATEGORY_FEATURES, axis=1, inplace=True)
gc.collect()
# Out:
# 112

# %%
train.head()
# Out:
#         item_id       user_id                  title  \
# 0  b912c3c6a6ad  e00f8ff2eaf9  Кокоби(кокон для сна)
# 1  2dac0150717d  39aeb48f0017      Стойка для Одежды
# 2  ba83aefab5dc  91e2f88dd6e3         Philips bluray
# 3  02996f1dd2ea  bf5cccea572d             Автокресло
# 4  7c90be56d2ab  ef50846afc0b         ВАЗ 2110, 2003
#
#                                          description       price  \
# 0  Кокон для сна малыша,пользовались меньше месяц...   400.00000
# 1          Стойка для одежды, под вешалки. С бутика.  3000.00000
# 2  В хорошем состоянии, домашний кинотеатр с blu ...  4000.00000
# 3                             Продам кресло от0-25кг  2200.00000
# 4                           Все вопросы по телефону. 40000.00000
#
#    item_seq_number activation_date  \
# 0                2      2017-03-28
# 1               19      2017-03-26
# 2                9      2017-03-20
# 3              286      2017-03-25
# 4                3      2017-03-16
#
#                                                image  deal_probability  \
# 0  d10c7e016e03247a3bf2d13348fe959fe6f436c1caf64c...           0.12789
# 1  79c9392cc51a9c81c6eb91eceb8e552171db39d7142700...           0.00000
# 2  b7f250ee3f39e1fedd77c141f273703f4a9be59db4b48a...           0.43177
# 3  e6ef97e0725637ea84e3d203e82dadb43ed3cc0a1c8413...           0.80323
# 4  54a687a3a0fc1d68aed99bdaaf551c5c70b761b16fd0a2...           0.20797
#
#    enc_region  enc_city  enc_parent_category_name  enc_category_name  \
# 0           3         1                         0                  1
# 1           2         3                         0                  0
# 2           4         1                         1                  0
# 3           4         0                         0                  1
# 4           2         1                         0                  1
#
#    enc_param_1  enc_param_2  enc_param_3  enc_user_type  enc_image_top_1
# 0            2            0            1              0       1008.00000
# 1            2            1            0              0        692.00000
# 2            1            0            1              0       3032.00000
# 3            2            0            0              1        796.00000
# 4            1            1            0              2       2264.00000

# %% [markdown]
# ## Feature Engineering
# ### Date Features

# %%
# Train data
train['month'] = train['activation_date'].dt.month
train['weekday'] = train['activation_date'].dt.weekday
train['month_day'] = train['activation_date'].dt.day
train['year_day'] = train['activation_date'].dt.dayofyear
# Test data
test['month'] = test['activation_date'].dt.month
test['weekday'] = test['activation_date'].dt.weekday
test['month_day'] = test['activation_date'].dt.day
test['year_day'] = test['activation_date'].dt.dayofyear

# %%
vectorizer = TfidfVectorizer(stop_words=stop_words, max_features=MAX_FEATURES)
vectorizer.fit(train['title'])
train_title_tfidf = vectorizer.transform(train['title'])
test_title_tfidf = vectorizer.transform(test['title'])
idf = vectorizer.idf_
vectorizer.vocabulary_
len(vectorizer.stop_words_)
# Out:
# 204799

# %%
vectorizer.vocabulary_
# Out:
# {'кокон': 1016,
#  'стойка': 1745,
#  'одежды': 1382,
#  'philips': 469,
#  'автокресло': 584,
#  'ваз': 682,
#  '2110': 88,
#  '2003': 64,
#  'авто': 583,
#  'люлька': 1179,
#  'водонагреватель': 725,
#  '100': 4,
#  'литров': 1167,
#  'платье': 1471,
#  'ботиночки': 660,
#  'натур': 1331,
#  'квартира': 975,
#  '25': 100,
#  'м²': 1182,
#  'эт': 1987,
#  'джинсы': 838,
#  'карты': 964,
#  'класс': 986,
#  'монитор': 1276,
#  'acer': 217,
#  '18': 41,
#  'продаются': 1546,
#  'щенки': 1964,
#  'овчарки': 1379,
#  'женское': 884,
#  'новое': 1347,
#  'chevrolet': 274,
#  'lanos': 398,
#  '2008': 69,
#  'цифра': 1908,
#  'куртка': 1135,
#  'весенняя': 703,
#  'осенняя': 1403,
#  'сниму': 1697,
#  'коттедж': 1077,
#  '44': 138,
#  'шапка': 1929,
#  'норковая': 1361,
#  'ford': 323,
#  'focus': 322,
#  '2005': 66,
#  'туфли': 1822,
#  'ботинки': 659,
#  'продаю': 1545,
#  'песочник': 1449,
#  'crockid': 285,
#  'панели': 1430,
#  'кулер': 1127,
#  'компьютера': 1047,
#  'комната': 1036,
#  'audi': 236,
#  '80': 193,
#  'коляска': 1027,
#  '2016': 77,
#  'года': 773,
#  'берцы': 635,
#  '70': 180,
#  'свадебные': 1641,
#  'брюки': 670,
#  'джинсовые': 836,
#  'летний': 1163,
#  'новый': 1352,
#  'шлем': 1946,
#  'футболка': 1880,
#  'adidas': 220,
#  'хорошее': 1892,
#  'состояние': 1711,
#  '13': 22,
#  '16': 33,
#  'полка': 1504,
#  'одеяло': 1383,
#  'детский': 826,
#  'развивающий': 1573,
#  'коврик': 1002,
#  'трость': 1809,
#  'набор': 1308,
#  'маникюра': 1202,
#  'сапожки': 1635,
#  'демисезонные': 812,
#  'next': 443,
#  '42': 136,
#  'юбки': 1989,
#  '300': 112,
#  'аквариум': 593,
#  'смартфон': 1692,
#  'explay': 316,
#  'белый': 628,
#  'комнату': 1038,
#  'матрас': 1213,
#  'сандали': 1628,
#  'размер': 1576,
#  '19': 43,
#  'новых': 1353,
#  'золото': 917,
#  '585': 162,
#  'мальчика': 1196,
#  'сандалики': 1630,
#  'комбинезон': 1033,
#  'ветровочный': 709,
#  'reima': 494,
#  'продам': 1544,
#  'куртку': 1137,
#  'polo': 475,
#  'монтаж': 1277,
#  'дверей': 793,
#  'наращивание': 1318,
#  'ногтей': 1355,
#  'сапоги': 1634,
#  'фирмы': 1869,
#  'carlo': 267,
#  'pazolini': 462,
#  'поросята': 1520,
#  'размера': 1577,
#  'кроссовки': 1122,
#  'детские': 825,
#  '34': 121,
#  'женская': 881,
#  'дубленка': 869,
#  'ортопедическая': 1396,
#  'обувь': 1376,
#  'натуральная': 1332,
#  'костюм': 1065,
#  'игры': 928,
#  'муж': 1288,
#  'час': 1914,
#  'сумка': 1758,
#  'синяя': 1671,
#  'роликовые': 1599,
#  'подарок': 1487,
#  'малыша': 1192,
#  '14': 25,
#  'хоккейная': 1887,
#  'форма': 1875,
#  'комплект': 1042,
#  '50': 150,
#  '52': 154,
#  'босоножки': 657,
#  'туфельки': 1821,
#  'стиральная': 1742,
#  'машина': 1219,
#  'lg': 407,
#  'кг': 978,
#  'гарантия': 759,
#  'весенние': 701,
#  'модуль': 1265,
#  'памяти': 1428,
#  'красивое': 1098,
#  'пальто': 1426,
#  'девочки': 803,
#  'ноутбуков': 1366,
#  'sony': 523,
#  'playstation': 472,
#  'one': 454,
#  '2002': 63,
#  'участок': 1856,
#  'сот': 1713,
#  'промназначения': 1554,
#  'яйцо': 1998,
#  'мужской': 1292,
#  'свитер': 1651,
#  'новые': 1351,
#  'платья': 1472,
#  'детскую': 830,
#  'стенку': 1735,
#  'весна': 704,
#  'осень': 1404,
#  'телевизор': 1772,
#  'цветной': 1900,
#  '2013': 74,
#  'мобильный': 1259,
#  'телефон': 1774,
#  'alcatel': 223,
#  'арт': 606,
#  'кеды': 979,
#  '24': 98,
#  'fi': 318,
#  'цвета': 1899,
#  'кенгуру': 980,
#  'дача': 789,
#  '20': 59,
#  'участке': 1855,
#  '10': 3,
#  '2107': 84,
#  '2001': 62,
#  'ищем': 947,
#  'кота': 1071,
#  'вязки': 748,
#  'билеты': 642,
#  'россии': 1600,
#  'рост': 1602,
#  '98': 210,
#  '104': 8,
#  'см': 1690,
#  'весенний': 702,
#  'lassie': 400,
#  'жк': 890,
#  'видеокамера': 716,
#  'бриджи': 665,
#  'ботильоны': 658,
#  '21': 79,
#  'вязаный': 746,
#  'серьги': 1663,
#  'куплю': 1133,
#  'квартиру': 976,
#  'детская': 824,
#  'классика': 988,
#  'германия': 766,
#  'газ': 751,
#  'газель': 752,
#  '2010': 71,
#  '54': 156,
#  'польша': 1513,
#  '11': 10,
#  '150': 29,
#  'мужские': 1290,
#  'часы': 1915,
#  'гараж': 756,
#  '12': 15,
#  'трикотажное': 1805,
#  'кукла': 1125,
#  'шкатулка': 1940,
#  'дом': 852,
#  '35': 122,
#  '30': 111,
#  'кресло': 1109,
#  'puma': 487,
#  'отличном': 1411,
#  'состоянии': 1712,
#  'шорты': 1949,
#  'картина': 960,
#  'новая': 1345,
#  'безрукавка': 624,
#  'mango': 419,
#  'жилетка': 889,
#  'ремонт': 1590,
#  'установка': 1846,
#  'мастер': 1209,
#  'toyota': 545,
#  'corolla': 283,
#  '1993': 50,
#  'кровать': 1113,
#  'samsung': 508,
#  'запчасти': 901,
#  'грузоперевозки': 783,
#  'ссср': 1723,
#  'кроватка': 1111,
#  'витрина': 720,
#  'скутер': 1683,
#  'кровля': 1115,
#  'самокат': 1625,
#  '65': 173,
#  'отделка': 1406,
#  'radeon': 489,
#  '43': 137,
#  'домик': 857,
#  'прогулочная': 1541,
#  'chicco': 275,
#  'торговое': 1795,
#  'помещение': 1515,
#  '78': 191,
#  'xbox': 567,
#  '360': 125,
#  '500': 151,
#  'гб': 762,
#  'потолок': 1526,
#  'оригинал': 1392,
#  'желетка': 879,
#  'xs': 571,
#  'волга': 729,
#  '2004': 65,
#  'темно': 1778,
#  'мес': 1235,
#  'кухонный': 1144,
#  'шкаф': 1941,
#  '39': 128,
#  'air': 222,
#  's7': 506,
#  '85': 199,
#  '3g': 130,
#  'обмен': 1369,
#  'компрессор': 1045,
#  'футболки': 1881,
#  'кофты': 1088,
#  'свитшот': 1652,
#  'боди': 650,
#  'уголок': 1833,
#  'выписку': 737,
#  'nissan': 446,
#  '1995': 52,
#  'колонки': 1022,
#  'zte': 579,
#  'blade': 252,
#  'языку': 1996,
#  '33': 119,
#  'suzuki': 534,
#  '750': 187,
#  'кольцо': 1026,
#  'hp': 357,
#  'мультиварка': 1295,
#  'tutis': 548,
#  'zippy': 578,
#  'sport': 525,
#  'plus': 473,
#  'очки': 1422,
#  'рубашки': 1607,
#  'лет': 1160,
#  'слип': 1686,
#  'маска': 1205,
#  'пиджак': 1455,
#  'mexx': 427,
#  'джинсовка': 834,
#  'дверь': 795,
#  'входная': 735,
#  'весну': 705,
#  '62': 169,
#  '68': 177,
#  'оборудование': 1373,
#  'аквариума': 594,
#  'юбка': 1988,
#  'мебель': 1229,
#  'заказ': 895,
#  'зимний': 914,
#  'huppa': 360,
#  '15': 28,
#  'рюкзак': 1620,
#  'подростка': 1492,
#  'комбез': 1030,
#  '134': 24,
#  'унитаз': 1841,
#  'акустическая': 598,
#  'система': 1673,
#  'yamaha': 572,
#  'школьная': 1943,
#  'черная': 1918,
#  'сарафан': 1636,
#  'блузка': 648,
#  'диван': 840,
#  '1991': 48,
#  'indesit': 368,
#  'guess': 345,
#  'by': 261,
#  'италия': 945,
#  'шапочка': 1932,
#  '40': 133,
#  'стол': 1746,
#  'книжка': 998,
#  'настольный': 1328,
#  'компьютер': 1046,
#  'кожаная': 1007,
#  'кожаные': 1011,
#  '38': 127,
#  'mitsubishi': 433,
#  'lancer': 396,
#  'водолазка': 724,
#  'galaxy': 327,
#  'отдам': 1405,
#  'щенков': 1965,
#  'кошечка': 1092,
#  'ищет': 948,
#  'сдам': 1654,
#  'офисное': 1417,
#  'уаз': 1828,
#  '1990': 47,
#  '45': 139,
#  'добрые': 849,
#  'руки': 1612,
#  'аппарат': 603,
#  'фирменный': 1868,
#  'купальник': 1130,
#  'натуральный': 1336,
#  'кожаный': 1012,
#  'тренажер': 1799,
#  '29': 105,
#  '2106': 83,
#  '1989': 46,
#  'плащ': 1473,
#  '2в1': 107,
#  'беременных': 633,
#  'love': 413,
#  'белья': 630,
#  'верхняя': 697,
#  'одежда': 1380,
#  'спальный': 1716,
#  'гарнитур': 760,
#  'lada': 395,
#  'kalina': 380,
#  'кованые': 1000,
#  'hm': 354,
#  'котел': 1072,
#  'демисезон': 809,
#  'угловой': 1832,
#  'компьютерный': 1049,
#  'трикотажная': 1804,
#  'монета': 1274,
#  'год': 772,
#  'музыкальный': 1294,
#  'центр': 1905,
#  'копеек': 1056,
#  'iphone': 373,
#  '5s': 165,
#  '32': 116,
#  'gb': 328,
#  'granta': 340,
#  '2017': 78,
#  'хорошем': 1893,
#  'фото': 1876,
#  'домов': 858,
#  'снт': 1698,
#  'днп': 848,
#  'домашние': 854,
#  'яйца': 1997,
#  'nike': 444,
#  'няня': 1367,
#  'курточка': 1138,
#  '46': 141,
#  '48': 144,
#  'ижс': 933,
#  '1998': 55,
#  'рубашка': 1606,
#  'юбочка': 1991,
#  'супер': 1762,
#  'ветровка': 707,
#  'ps4': 485,
#  '1tb': 58,
#  'dvd': 307,
#  'прыгунки': 1559,
#  '2015': 76,
#  'демисезонный': 813,
#  '110': 11,
#  '116': 14,
#  '22': 94,
#  'intel': 370,
#  'core': 282,
#  'i5': 363,
#  '650': 174,
#  'костюмчик': 1066,
#  'отличный': 1412,
#  'атлант': 608,
#  'наличии': 1316,
#  '128gb': 21,
#  'услуги': 1845,
#  'зима': 911,
#  'отопление': 1413,
#  'пол': 1502,
#  'весы': 706,
#  'уборка': 1829,
#  'квартир': 974,
#  'женские': 882,
#  'готовый': 781,
#  'бизнес': 640,
#  '2000': 61,
#  'универсальный': 1839,
#  'блок': 645,
#  'питания': 1461,
#  'осенние': 1401,
#  '27': 103,
#  'разм': 1575,
#  'дизайн': 841,
#  'peugeot': 468,
#  '2011': 72,
#  '3в1': 131,
#  'ветровку': 708,
#  'j1': 376,
#  'mini': 432,
#  'деревянный': 821,
#  'браслет': 663,
#  'сандалии': 1629,
#  'идеальном': 931,
#  'ролики': 1598,
#  'лего': 1158,
#  'продается': 1542,
#  'чайник': 1912,
#  'zara': 576,
#  'когтеточка': 1004,
#  'комплекс': 1041,
#  'кошки': 1094,
#  'плед': 1475,
#  'pro': 482,
#  'велосипед': 690,
#  'холодильник': 1890,
#  's6': 505,
#  'интернет': 942,
#  'роутер': 1603,
#  'мегафон': 1230,
#  'подставка': 1496,
#  'письменный': 1459,
#  'кимоно': 982,
#  'бу': 673,
#  'банки': 617,
#  'daewoo': 289,
#  'nexia': 442,
#  'игровой': 924,
#  'вязка': 747,
#  'цветок': 1902,
#  'зеркало': 909,
#  'га': 750,
#  '82': 196,
#  'резиновые': 1587,
#  'тренажёр': 1800,
#  'мягкий': 1303,
#  'золотой': 919,
#  'репетитор': 1591,
#  'костюмчики': 1067,
#  'кабель': 950,
#  'горный': 778,
#  'женский': 883,
#  'mothercare': 435,
#  'ортопедические': 1397,
#  'золотые': 920,
#  'свадебное': 1640,
#  'продаётся': 1547,
#  'озу': 1384,
#  '240': 99,
#  'hdd': 349,
#  '500gb': 152,
#  'кофта': 1084,
#  'конверт': 1051,
#  'and': 227,
#  'lacetti': 393,
#  'айфон': 591,
#  'замшевые': 900,
#  'электроплита': 1983,
#  'electrolux': 312,
#  'пылесос': 1562,
#  'гарантии': 758,
#  'малышей': 1193,
#  'плата': 1468,
#  's4': 503,
#  'мешок': 1249,
#  '200': 60,
#  '60': 166,
#  'wi': 562,
#  'покрытие': 1500,
#  'гель': 764,
#  'лаком': 1149,
#  'профессиональная': 1555,
#  'led': 402,
#  'лампа': 1150,
#  'вт': 734,
#  'топ': 1793,
#  'котята': 1080,
#  'sc': 510,
#  'матрац': 1216,
#  'икея': 937,
#  'кофточка': 1085,
#  'экскаватор': 1970,
#  'hitachi': 353,
#  'гостиная': 780,
#  'красивые': 1099,
#  'мангал': 1199,
#  'корпус': 1061,
#  'мужская': 1289,
#  'машинки': 1221,
#  'штаны': 1952,
#  'маятник': 1227,
#  'собак': 1700,
#  'машинка': 1220,
#  'морской': 1281,
#  'ноутбук': 1364,
#  'ariston': 229,
#  'оперативная': 1390,
#  'память': 1429,
#  'ddr3': 292,
#  '2gb': 106,
#  'модель': 1261,
#  'тумба': 1816,
#  'вещи': 713,
#  'книга': 996,
#  'мир': 1254,
#  'пакет': 1423,
#  'вечернее': 710,
#  'rose': 499,
#  'книги': 997,
#  'шуба': 1957,
#  'крем': 1107,
#  '66': 175,
#  'сумки': 1759,
#  '26': 102,
#  'сказка': 1677,
#  'ручки': 1616,
#  'стеллаж': 1730,
#  'книг': 995,
#  'чехол': 1923,
#  'телефона': 1775,
#  'kia': 383,
#  'cee': 271,
#  'мясорубка': 1306,
#  'дома': 853,
#  'строительные': 1751,
#  'работы': 1566,
#  'benetton': 247,
#  'полуботинки': 1507,
#  'носки': 1362,
#  'колготки': 1017,
#  'люстра': 1180,
#  '17': 39,
#  'chery': 273,
#  '2006': 67,
#  'парка': 1433,
#  'деми': 808,
#  'стул': 1755,
#  'кормления': 1058,
#  'шуруповерт': 1961,
#  'слипоны': 1687,
#  'витрины': 721,
#  'летняя': 1164,
#  'lumia': 415,
#  'дерево': 817,
#  '1997': 54,
#  'станок': 1725,
#  'виды': 719,
#  'металлическая': 1240,
#  'урал': 1843,
#  '36': 124,
#  'кроликов': 1120,
#  'девочку': 804,
#  'возраст': 728,
#  'валенки': 684,
#  '250': 101,
#  '2007': 68,
#  'дрель': 865,
#  'полушубок': 1512,
#  'меха': 1245,
#  'z3': 574,
#  'смарт': 1691,
#  '79': 192,
#  'подгузники': 1490,
#  'взрослых': 714,
#  'труба': 1810,
#  'бровей': 667,
#  'обменяю': 1370,
#  'мотоцикл': 1284,
#  'розовый': 1597,
#  'подушка': 1497,
#  'металл': 1239,
#  'нарядные': 1323,
#  'маз': 1186,
#  'игрушки': 927,
#  'meizu': 425,
#  'm2': 416,
#  'печь': 1453,
#  'бани': 616,
#  'камаз': 952,
#  '96': 209,
#  'стульчик': 1756,
#  'смеситель': 1693,
#  'швейная': 1935,
#  'юбку': 1990,
#  'домашний': 855,
#  'халат': 1883,
#  'генератор': 765,
#  'nokia': 448,
#  'demar': 296,
#  '64': 171,
#  'x2': 564,
#  'пресс': 1532,
#  '600': 167,
#  'мл': 1256,
#  'плиты': 1482,
#  'kids': 384,
#  'бутсы': 677,
#  'породам': 1518,
#  'джойстик': 839,
#  'pentium': 466,
#  '4gb': 147,
#  'msi': 437,
#  'gtx': 344,
#  'гантели': 755,
#  'пары': 1436,
#  'полусапожки': 1511,
#  '2112': 90,
#  'полный': 1505,
#  'ванночка': 687,
#  'горка': 776,
#  'купания': 1131,
#  'комод': 1040,
#  'niva': 447,
#  'самсунг': 1627,
#  'планшет': 1464,
#  'джинсовый': 837,
#  'толстовка': 1790,
#  'котик': 1075,
#  '55': 157,
#  'нарядное': 1322,
#  'декоративная': 805,
#  'зимние': 913,
#  'rio': 498,
#  'демисезонное': 811,
#  'настройка': 1329,
#  'доска': 861,
#  'матрасом': 1215,
#  'постельное': 1523,
#  'белье': 629,
#  'hyundai': 361,
#  'getz': 333,
#  'любой': 1175,
#  'сложности': 1689,
#  'маленькой': 1191,
#  'балетки': 612,
#  'корова': 1060,
#  'объектив': 1378,
#  '58': 161,
#  'mm': 434,
#  'sela': 514,
#  'светильники': 1648,
#  'обои': 1372,
#  'обслуживание': 1374,
#  'мощный': 1285,
#  'нат': 1330,
#  'кожи': 1014,
#  'снегоход': 1695,
#  '4s': 148,
#  '8gb': 203,
#  'газовая': 753,
#  'колонка': 1021,
#  'экран': 1969,
#  'котофей': 1076,
#  'электрика': 1973,
#  'сруб': 1722,
#  'куртки': 1136,
#  'lenovo': 405,
#  'двери': 794,
#  'волосы': 731,
#  '2012': 73,
#  'системный': 1675,
#  'жилет': 888,
#  'утепленный': 1850,
#  'кролики': 1119,
#  'декоративные': 806,
#  'sm': 520,
#  'ручной': 1618,
#  '2114': 92,
#  'samara': 507,
#  'мм': 1257,
#  'бортики': 656,
#  'кроватку': 1112,
#  'аренда': 604,
#  'ходунки': 1886,
#  'micromax': 430,
#  'утюг': 1853,
#  'девочка': 802,
#  'кардиган': 958,
#  '59': 163,
#  'прицеп': 1539,
#  'летние': 1162,
#  'тонкий': 1791,
#  'аренду': 605,
#  'кожа': 1006,
#  'детское': 828,
#  'руль': 1613,
#  'defender': 294,
#  'спортивная': 1719,
#  'легкая': 1155,
#  'офис': 1415,
#  'магазин': 1183,
#  'автомат': 586,
#  'металлический': 1242,
#  'велотренажер': 692,
#  'torneo': 542,
#  'утепленные': 1849,
#  'производственное': 1551,
#  'выпускной': 741,
#  'цыплята': 1910,
#  'jeans': 377,
#  'штукатурка': 1955,
#  'пуховик': 1561,
#  'supra': 533,
#  'самосвал': 1626,
#  'соболь': 1704,
#  'вещей': 712,
#  'bluetooth': 254,
#  'macbook': 417,
#  '2009': 70,
#  'насос': 1324,
#  'зарядное': 904,
#  'устройство': 1847,
#  'кошелёк': 1091,
#  'fly': 321,
#  'косуха': 1069,
#  'принцессы': 1536,
#  'бассейн': 619,
#  'джинсовая': 833,
#  'кирпич': 984,
#  'красный': 1105,
#  '6s': 179,
#  '16gb': 37,
#  'переноска': 1444,
#  'деревьев': 818,
#  'бандаж': 615,
#  'xl': 569,
#  'стулья': 1757,
#  'ikea': 366,
#  'asus': 235,
#  'zenfone': 577,
#  '16гб': 38,
#  'покрывало': 1499,
#  'летнее': 1161,
#  'пвх': 1437,
#  'окон': 1388,
#  'учебник': 1857,
#  'ps3': 484,
#  'бюстгальтер': 681,
#  'нетбук': 1341,
#  'красивый': 1100,
#  'номер': 1358,
#  'вывоз': 736,
#  'мусора': 1296,
#  'доставка': 862,
#  'итальянские': 946,
#  'диск': 842,
#  'psp': 486,
#  'окно': 1387,
#  'телефоны': 1777,
#  'игровая': 923,
#  'зимняя': 915,
#  'материнская': 1211,
#  'процессор': 1558,
#  'i3': 362,
#  'reserved': 497,
#  'строительство': 1753,
#  'коттеджей': 1078,
#  'отделочные': 1407,
#  'стелька': 1732,
#  'двух': 799,
#  'угги': 1830,
#  'модные': 1264,
#  '122': 18,
#  '1996': 53,
#  'теплые': 1782,
#  'пинетки': 1458,
#  'renault': 495,
#  'logan': 411,
#  'бриллиантами': 666,
#  'лето': 1165,
#  'ядра': 1994,
#  'любых': 1177,
#  'корм': 1057,
#  '120': 16,
#  'кран': 1096,
#  'сантехник': 1632,
#  'коллекция': 1020,
#  'сварочный': 1646,
#  'in': 367,
#  'танкетке': 1764,
#  'рабочий': 1569,
#  'блузки': 649,
#  'окна': 1386,
#  'пластиковые': 1466,
#  'перчатки': 1447,
#  'хлопок': 1885,
#  'учебники': 1858,
#  'класса': 987,
#  'свободного': 1653,
#  'назначения': 1312,
#  'aspire': 233,
#  'нож': 1356,
#  'xiaomi': 568,
#  'дрова': 866,
#  'a5': 213,
#  'коньки': 1055,
#  'горнолыжный': 777,
#  'art': 231,
#  'демисезонная': 810,
#  'выпускное': 740,
#  'extronic': 317,
#  'испания': 944,
#  'студия': 1754,
#  'блоки': 646,
#  'молокоотсос': 1271,
#  'touch': 544,
#  'ddr': 290,
#  '1gb': 57,
#  'золотое': 918,
#  'пробы': 1540,
#  'вес': 698,
#  'конструктор': 1053,
#  'шапки': 1930,
#  '86': 200,
#  'игрушка': 926,
#  'кошка': 1093,
#  'max': 421,
#  '90': 204,
#  'жакет': 876,
#  'стенка': 1734,
#  'офисов': 1419,
#  '3d': 129,
#  '57': 160,
#  'перфоратор': 1446,
#  'красные': 1104,
#  'prestigio': 478,
#  'приставка': 1537,
#  'камера': 954,
#  'большая': 653,
#  'шт': 1950,
#  'ключ': 994,
#  'kingston': 386,
#  '32gb': 118,
#  'волос': 730,
#  'шерсть': 1937,
#  '56': 159,
#  'шторы': 1953,
#  'volkswagen': 556,
#  'golf': 337,
#  'плита': 1478,
#  'электрическая': 1974,
#  'кобель': 999,
#  'вязку': 749,
#  'спортивный': 1721,
#  'тёплый': 1827,
#  'ремень': 1589,
#  'клавиатура': 985,
#  'тени': 1779,
#  'stinger': 530,
#  '320': 117,
#  'игр': 921,
#  'евро': 874,
#  'red': 491,
#  'лосины': 1172,
#  'очень': 1421,
#  'бижутерия': 639,
#  'каталка': 965,
#  'музыкальная': 1293,
#  'коляску': 1029,
#  '400': 134,
#  'комбенизон': 1032,
#  'инвалидная': 939,
#  '2х': 109,
#  'opel': 455,
#  '1987': 44,
#  'саженцы': 1622,
#  'полукомбинезон': 1508,
#  'белые': 627,
#  'сварка': 1644,
#  'пакетом': 1424,
#  '63': 170,
#  'маршрутизатор': 1204,
#  'видеокарта': 717,
#  'ddr2': 291,
#  'чайный': 1913,
#  '92': 206,
#  '71': 182,
#  'фотоаппарат': 1877,
#  'nikon': 445,
#  'тапочки': 1766,
#  'цвет': 1898,
#  'mercedes': 426,
#  'benz': 249,
#  'classic': 278,
#  'модем': 1262,
#  'tp': 546,
#  'link': 409,
#  'выпускного': 739,
#  '800': 194,
#  'журнальный': 892,
#  'столик': 1747,
#  'межкомнатные': 1233,
#  'матрасик': 1214,
#  'seagate': 513,
#  'фирма': 1865,
#  'сумочка': 1761,
#  'мфу': 1298,
#  'марки': 1203,
#  'курточку': 1140,
#  'журналы': 891,
#  'брючки': 671,
#  'круг': 1123,
#  'мини': 1253,
#  'праздничное': 1530,
#  'беременной': 632,
#  'a4': 212,
#  '23': 96,
#  '03': 2,
#  'мышь': 1300,
#  'mazda': 422,
#  'apple': 228,
#  'power': 476,
#  '350': 123,
#  'pc': 463,
#  'автолюлька': 585,
#  'forward': 324,
#  'машинку': 1222,
#  'стрижки': 1750,
#  'комбинезоны': 1034,
#  'котят': 1079,
#  'праздник': 1529,
#  'пижама': 1456,
#  'утеплённый': 1852,
#  'sportage': 526,
#  'игрушек': 925,
#  '37': 126,
#  '160': 34,
#  'турция': 1820,
#  'шезлонг': 1936,
#  'jetem': 378,
#  'цепочка': 1906,
#  ...}

# %%
idf
# Out:
# array([8.77912514, 9.45181527, 7.69761642, ..., 9.28045702, 8.35736532,
#        9.54650259])

# %%
len(vectorizer.get_feature_names())
# Out:
# 2000

# %%
x_train_csr = csr_matrix(hstack([train[ENCODED_CATEGORY_FEATURES + NUMBER_FEATURES + GENERATED_DATE_FEATURES], train_title_tfidf]))
x_test_csr = csr_matrix(hstack([test[ENCODED_CATEGORY_FEATURES + NUMBER_FEATURES + GENERATED_DATE_FEATURES], test_title_tfidf]))

# %%
X_train, X_valid, y_train, y_valid = train_test_split(x_train_csr, train[TARGET_FEATURE], test_size=0.20, random_state=42)

# %%
num_round = 5000
params = {'learning_rate': 0.05,
          'max_depth': 7,
          'boosting': 'gbdt',
          'objective': 'regression',
          'metric': ['auc','rmse'],
          'is_training_metric': True,
          'seed': 19,
          'num_leaves': 128,
          'feature_fraction': 0.9,
          'bagging_fraction': 0.8,
          'bagging_freq': 5}
model = lgb.train(params, lgb.Dataset(X_train, label=y_train), num_round, valid_sets=lgb.Dataset(X_valid, label=y_valid), verbose_eval=50, early_stopping_rounds=100)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's rmse: 0.239674	valid_0's auc: 0.735872
# [100]	valid_0's rmse: 0.237102	valid_0's auc: 0.741951
# [150]	valid_0's rmse: 0.235776	valid_0's auc: 0.743872
# [200]	valid_0's rmse: 0.234762	valid_0's auc: 0.745753
# [250]	valid_0's rmse: 0.2342	valid_0's auc: 0.746793
# [300]	valid_0's rmse: 0.233695	valid_0's auc: 0.747693
# [350]	valid_0's rmse: 0.233233	valid_0's auc: 0.748174
# [400]	valid_0's rmse: 0.23286	valid_0's auc: 0.749154
# [450]	valid_0's rmse: 0.232522	valid_0's auc: 0.750043
# [500]	valid_0's rmse: 0.232187	valid_0's auc: 0.750893
# [550]	valid_0's rmse: 0.231966	valid_0's auc: 0.75133
# [600]	valid_0's rmse: 0.231698	valid_0's auc: 0.751585
# [650]	valid_0's rmse: 0.231511	valid_0's auc: 0.752036
# [700]	valid_0's rmse: 0.231281	valid_0's auc: 0.752495
# [750]	valid_0's rmse: 0.231119	valid_0's auc: 0.75279
# [800]	valid_0's rmse: 0.230939	valid_0's auc: 0.753301
# [850]	valid_0's rmse: 0.230761	valid_0's auc: 0.753524
# [900]	valid_0's rmse: 0.230582	valid_0's auc: 0.753919
# [950]	valid_0's rmse: 0.230426	valid_0's auc: 0.754374
# [1000]	valid_0's rmse: 0.230311	valid_0's auc: 0.754668
# [1050]	valid_0's rmse: 0.230158	valid_0's auc: 0.755185
# [1100]	valid_0's rmse: 0.230055	valid_0's auc: 0.755429
# [1150]	valid_0's rmse: 0.22993	valid_0's auc: 0.755608
# [1200]	valid_0's rmse: 0.229827	valid_0's auc: 0.755927
# [1250]	valid_0's rmse: 0.229713	valid_0's auc: 0.756212
# [1300]	valid_0's rmse: 0.229613	valid_0's auc: 0.75643
# [1350]	valid_0's rmse: 0.229507	valid_0's auc: 0.756772
# [1400]	valid_0's rmse: 0.229406	valid_0's auc: 0.756884
# [1450]	valid_0's rmse: 0.229316	valid_0's auc: 0.757239
# [1500]	valid_0's rmse: 0.229249	valid_0's auc: 0.757363
# [1550]	valid_0's rmse: 0.229173	valid_0's auc: 0.757625
# [1600]	valid_0's rmse: 0.229085	valid_0's auc: 0.757797
# [1650]	valid_0's rmse: 0.229006	valid_0's auc: 0.758047
# [1700]	valid_0's rmse: 0.228933	valid_0's auc: 0.758248
# [1750]	valid_0's rmse: 0.228879	valid_0's auc: 0.758458
# [1800]	valid_0's rmse: 0.228812	valid_0's auc: 0.758639
# [1850]	valid_0's rmse: 0.228749	valid_0's auc: 0.758776
# [1900]	valid_0's rmse: 0.228709	valid_0's auc: 0.758823
# [1950]	valid_0's rmse: 0.228658	valid_0's auc: 0.758973
# [2000]	valid_0's rmse: 0.228596	valid_0's auc: 0.759187
# [2050]	valid_0's rmse: 0.228558	valid_0's auc: 0.75935
# [2100]	valid_0's rmse: 0.228511	valid_0's auc: 0.759415
# [2150]	valid_0's rmse: 0.228467	valid_0's auc: 0.759597
# [2200]	valid_0's rmse: 0.228425	valid_0's auc: 0.759733
# [2250]	valid_0's rmse: 0.22838	valid_0's auc: 0.759753
# [2300]	valid_0's rmse: 0.22833	valid_0's auc: 0.759828
# [2350]	valid_0's rmse: 0.228292	valid_0's auc: 0.760155
# [2400]	valid_0's rmse: 0.228244	valid_0's auc: 0.760115
# [2450]	valid_0's rmse: 0.228211	valid_0's auc: 0.760298
# [2500]	valid_0's rmse: 0.228184	valid_0's auc: 0.760423
# [2550]	valid_0's rmse: 0.228143	valid_0's auc: 0.76045
# [2600]	valid_0's rmse: 0.228121	valid_0's auc: 0.760492
# [2650]	valid_0's rmse: 0.228102	valid_0's auc: 0.760576
# [2700]	valid_0's rmse: 0.228074	valid_0's auc: 0.76065
# [2750]	valid_0's rmse: 0.22805	valid_0's auc: 0.760702
# [2800]	valid_0's rmse: 0.228003	valid_0's auc: 0.760761
# [2850]	valid_0's rmse: 0.227993	valid_0's auc: 0.760807
# [2900]	valid_0's rmse: 0.227967	valid_0's auc: 0.760946
# [2950]	valid_0's rmse: 0.227947	valid_0's auc: 0.760886
# [3000]	valid_0's rmse: 0.227919	valid_0's auc: 0.761111
# [3050]	valid_0's rmse: 0.227899	valid_0's auc: 0.761027
# Early stopping, best iteration is:
# [2994]	valid_0's rmse: 0.227922	valid_0's auc: 0.761159

# %%
pred = model.predict(x_test_csr)

submission = pd.read_csv("../data/raw/sample_submission.csv")
submission['deal_probability'] = pred
submission['deal_probability'].clip(0.0, 1.0, inplace=True)
submission.to_csv('../data/submissions/submission.csv', index=False)

# Compress (zip) submission file.
submission_zip = zipfile.ZipFile('../data/submissions/submission.csv.zip', 'w')
submission_zip.write('../data/submissions/submission.csv', compress_type=zipfile.ZIP_DEFLATED)
submission_zip.close()

submission
# Out:
#              item_id  deal_probability
# 0       6544e41a8817           0.89921
# 1       65b9484d670f           0.45429
# 2       8bab230b2ecd           0.40685
# 3       8e348601fefc           0.53624
# 4       8bd2fe400b89           0.53550
# 5       c63dbd6c657f           0.55200
# 6       6d1a410df86e           0.36032
# 7       e8d3e7922b80           0.36406
# 8       2bc1ab208462           0.36030
# 9       7e05d77a9181           0.47045
# 10      e2ec19a3ca2b           0.52882
# 11      68069bfc06c2           0.41739
# 12      595842ba248a           0.76428
# 13      4130d5cfc5de           0.37666
# 14      c21ede41b256           0.51205
# 15      f56e4684ceda           0.53180
# 16      e7ab88d19965           0.37554
# 17      81c1cd9f4e4e           0.41195
# 18      2c989cea0e97           0.42296
# 19      36a35020ebeb           0.84490
# 20      60b0cc9cf25e           0.45158
# 21      ac0a01acccc2           0.43150
# 22      683c444d6a40           0.65309
# 23      5580ccd3358a           0.33857
# 24      4596527723ec           1.00000
# 25      2e414b752d9f           0.33852
# 26      032e21134f2f           0.35498
# 27      fd6f6a2ed415           0.50413
# 28      44da737c70af           0.40712
# 29      272e2ee33c62           0.59506
# ...              ...               ...
# 508408  df8001ca5897           0.45106
# 508409  0455281c86fb           0.53897
# 508410  482d3253c9f1           0.38078
# 508411  9278e7c14cd0           0.37231
# 508412  9041d0340b49           0.39246
# 508413  872c382ce446           0.48155
# 508414  67448ad8941c           0.56962
# 508415  6ffaf4c20469           0.47760
# 508416  acc46dbda733           0.41428
# 508417  eb33cd6dac70           0.50139
# 508418  f9db673cb425           0.34349
# 508419  32727c2ed7e5           0.35907
# 508420  2e6f289d2676           0.35801
# 508421  58fa2c39f791           0.45645
# 508422  0e1a370c12c7           0.38116
# 508423  cc4f7fd3d2f2           0.55250
# 508424  29a342aa8508           0.42238
# 508425  fce6b0de65f8           0.44855
# 508426  dae17c1850b0           0.51800
# 508427  549b1c9354e3           0.49519
# 508428  0915772bb21c           0.41646
# 508429  d8984ced6639           0.67944
# 508430  e7c68be28a03           0.41572
# 508431  a96a4c5ad75a           0.37963
# 508432  fdcd9910edf3           0.48083
# 508433  9f2200aed300           0.52502
# 508434  70813f518de4           0.42694
# 508435  a22a2eeb5dd2           0.40129
# 508436  ed7fbb0733c1           0.74735
# 508437  d374d332992f           0.50965
#
# [508438 rows x 2 columns]
